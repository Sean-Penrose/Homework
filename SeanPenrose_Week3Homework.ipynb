# %% [markdown]
# ### **1. What is an algorithm?** ###
#
# Answer- An Algorithm is a series of steps used to solve a given problem.
#
# ### **2. Variable names may not start with certain characters - name two.** ###
#
# Answer- Two examples are an Special characters like and any number.
#
# ### **3. What is a Semantic error?** ###
#
# Answer- Semantic errors happen when the code we put in runs but with incorrect results. These will not produce an error messange like syntax errors and is grammatically correct.
#
# ### **4. What is the #1 rule of coding / debugging?** ###
#
# Answer- Complexity is the enemy of efficiency!
#
# ### **5. List 5 Python reserved words.** ###
#
# Answer- TRUE, FALSE, AND, ELSE, IS

# %%
#Question 6
aboutme = """
My name is Sean Penrose
My favorite food is Sushi
My dream job is to become a Data Analyist
"""
print (aboutme)

#Question 7
#string
myname = "Sean"
#integer
myage = 27
#Boolean
married = True
#Dictionary
SpiderMen = {"Tobey Maguire" : "Peter 2", "Andrew Garfield" : "Peter 3", "Tom Holland" : "Peter 1"}
#List
sushilist = ["salmon", "seaweed", "rice", "siracha"]

#Question 7.1 Print the length of your string
print(len(myname)) 

#Question 7.2 Print the index value of the 4th character in your string
print(myname[3])

#Question 8
savvy = "Learning Data Analytics and Python is Awesome!"
print(savvy[5:23])
savvy = "Learning Data Analytics and Python is Awesome!"
print(savvy.replace("Awesome", "Great"))
print(savvy)
if "Python" in savvy:
    print("Yes 'Python' is present")
    
#Question 9
name, age, length = "Sean", 27, 6.0
minibio = (f"Hi my name is {name}, I am {length} and {age} old today")
print(minibio)
agefloat = float(age)
print(agefloat)
# Out:
# My name is Sean Penrose
# My favorite food is Sushi
# My dream job is to become a Data Analyist
#
# 4
# n
# ing Data Analytics
# Learning Data Analytics and Python is Great!
# Learning Data Analytics and Python is Awesome!
# Yes 'Python' is present
# Hi my name is Sean, I am 6.0 and 27 old today
# 27.0

# %%
#Question 10
mylist = ["Chili","Onions", "Sour Cream", "Peppers", 5,]

mylist[1] ="Salt"
print(mylist)
mylist.append("Pepper")
mylist.append("Rice")
print(mylist)

print(len(mylist))
mylist_2 = mylist[0:3]
print(mylist_2)
mylist.extend(mylist_2)
print(mylist)
simList = ["Sean", "Lindsey", "Asia", "Erin", "Brandon"]
simList.sort()
print(simList)
myList4 = mylist_2 + simList
print(myList4)
# Out:
# ['Chili', 'Salt', 'Sour Cream', 'Peppers', 5]
# ['Chili', 'Salt', 'Sour Cream', 'Peppers', 5, 'Pepper', 'Rice']
# 7
# ['Chili', 'Salt', 'Sour Cream']
# ['Chili', 'Salt', 'Sour Cream', 'Peppers', 5, 'Pepper', 'Rice', 'Chili', 'Salt', 'Sour Cream']
# ['Asia', 'Brandon', 'Erin', 'Lindsey', 'Sean']
# ['Chili', 'Salt', 'Sour Cream', 'Asia', 'Brandon', 'Erin', 'Lindsey', 'Sean']

# %%
#Question 13
student = {
    "name" :"Peter",
    "age" : 18,
    "height" : 5.8,
    "enrolled" : True,
    "classes": ["Social Studies", "Biology", "Calculus", "World History", "American Government", "Creative Writing"],
    }
print(student)

#Print out 1 value
name_value = student.get("name")
print(name_value)
# Replace any one value in your dictionary with your name
student.update({"name" : "Sean"})
print(student.get("name"))

#Add your favorite color to the dictionary
student.update({"Favorite Color" : "Red"})
print(student)

#Add a list, tuple or set to your dictionary
student["Lesser Colors"] = "Grey", "White", 
print(student)

#Print a list of the dictionary keys
all_keys =student.keys()
print(all_keys)

#Print a list of the dictionary values
all_values =student.values()
print(all_values)

#Copy your 1st dictionary into a 2nd dictionary
import copy
studentcopy = copy.copy(student)
print(studentcopy)

#Pop an item from the 2nd dictionary, and print the dictionary
studentcopy.popitem ()
print(studentcopy)

#Remove all the elements from the 2nd dictionary and print the result
studentcopy.clear()
print(studentcopy)
# Out:
# {'name': 'Peter', 'age': 18, 'height': 5.8, 'enrolled': True, 'classes': ['Social Studies', 'Biology', 'Calculus', 'World History', 'American Government', 'Creative Writing']}
# Peter
# Sean
# {'name': 'Sean', 'age': 18, 'height': 5.8, 'enrolled': True, 'classes': ['Social Studies', 'Biology', 'Calculus', 'World History', 'American Government', 'Creative Writing'], 'Favorite Color': 'Red'}
# {'name': 'Sean', 'age': 18, 'height': 5.8, 'enrolled': True, 'classes': ['Social Studies', 'Biology', 'Calculus', 'World History', 'American Government', 'Creative Writing'], 'Favorite Color': 'Red', 'Lesser Colors': ('Grey', 'White')}
# dict_keys(['name', 'age', 'height', 'enrolled', 'classes', 'Favorite Color', 'Lesser Colors'])
# dict_values(['Sean', 18, 5.8, True, ['Social Studies', 'Biology', 'Calculus', 'World History', 'American Government', 'Creative Writing'], 'Red', ('Grey', 'White')])
# ...
